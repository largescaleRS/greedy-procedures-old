# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *
# https://albertcthomas.github.io/good-practices-random-number-generators/
# plt.rcParams["font.sans-serif"] = "Arial Unicode MS"
plt.rcParams["font.sans-serif"] = "DejaVu Sans"
# plt.rcParams["axes.unicode_minus"] = False
# mlib.rc('xtick', labelsize=15) 
# mlib.rc('ytick', labelsize=15) |
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# RayContext(dashboard_url='', python_version='3.8.0', ray_version='1.13.0', ray_commit='e4ce38d001dbbe09cd21c497fedd03d692b2be3e', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:63259', 'raylet_socket_name': 'tcp://127.0.0.1:63524', 'webui_url': '', 'session_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ray\\session_2022-12-29_14-28-44_556232_15100', 'metrics_export_port': 64884, 'gcs_address': '127.0.0.1:64710', 'address': '127.0.0.1:64710', 'node_id': '8aaf0d4c7c175073ed1fbf742b728ea91ddd0a2c4c3ec9eaf564d7f1'})

# %%
from TpMaxSimulator import TpMaxSimulator

# %%
problem_types = [20, 30, 50]
recipes0 = [30, 50, 100]
recipes1 = [(2, 28), (4, 44), (9, 91)]
recipes2 = [(27, 3), (45, 5), (90, 10)]
recipes3 = [(6, 21, 3), (10, 35, 5), (20, 70, 10)]
recipes4 = [30, 50, 100]
n_recipe = 3
G = 11
n_replications = 500
seed = 20221229
_njobs, _nstages, _burnin = 2050, 3, 2000

# %%
np.random.seed(seed)

# %%
rng = np.random.default_rng(seed)
FBKT_results = []
FBKTS_results = []
EFG_results = []
EFGPlus_results = []
MoSH_results = []

# %%
# Warning info is due to the number of parallelization tasks  temporally exceeds the available cpus.  It does not influence the PCS result.

# %%
for problem_type in problem_types:
    slns, means = loadTrue(problem_type)
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
        
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:3249
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:28:51 2022
# PCS:0.326, PGS:0.798
# Total time used: 161.34494543075562s, simulation ends at Thu Dec 29 14:31:31 2022
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:31:32 2022
# PCS:0.362, PGS:0.852
# Total time used: 166.6627914905548s, simulation ends at Thu Dec 29 14:34:18 2022
# EFG
# --------New experiments with  k=3249----------------------
# (remote_FBKT pid=14176) E1229 14:34:18.220000000 30592 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=40596) E1229 14:34:18.275000000 43600 src/core/ext/transport/chttp2/transport/chttp2_transport.cc
# (remote_FBKT pid=40596) :
# (remote_FBKT pid=40596) 1
# (remote_FBKT pid=40596) 1
# (remote_FBKT pid=40596) 0
# (remote_FBKT pid=40596) 3]
# (remote_FBKT pid=40596) R
# (remote_FBKT pid=40596) e
# (remote_FBKT pid=40596) ce
# (remote_FBKT pid=40596) i
# (remote_FBKT pid=40596) ved
# (remote_FBKT pid=40596)
# (remote_FBKT pid=40596) a
# (remote_FBKT pid=20624) E1229 14:34:18.281000000 21120 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:
# (remote_FBKT pid=20624) 1103]
# (remote_FBKT pid=20624) R
# (remote_FBKT pid=20624) ec
# (remote_FBKT pid=20624) e
# (remote_FBKT pid=20624) i
# (remote_FBKT pid=20624) v
# (remote_FBKT pid=20624) e
# (remote_FBKT pid=20624) d
# (remote_FBKT pid=20624)
# (remote_FBKT pid=20624) a
# (remote_FBKT pid=20624)
# (remote_FBKT pid=20624) G
# (remote_FBKT pid=20624) O
# (remote_FBKT pid=20624) AWA
# (remote_FBKT pid=20624) Y w
# (remote_FBKT pid=20624) i
# (remote_FBKT pid=20624) t
# (remote_FBKT pid=20624) h
# (remote_FBKT pid=20624)  e
# (remote_FBKT pid=20624) rr
# (remote_FBKT pid=20624) or
# (remote_FBKT pid=20624)
# (remote_FBKT pid=20624) c
# (remote_FBKT pid=20624) ode
# (remote_FBKT pid=20624) ENH
# (remote_FBKT pid=20624) A
# (remote_FBKT pid=20624) NCE_YO
# (remote_FBKT pid=20624) UR
# (remote_FBKT pid=20624) _CALM a
# (remote_FBKT pid=20624) n
# (remote_FBKT pid=20624) d debug d
# (remote_FBKT pid=20624) a
# (remote_FBKT pid=20624) ta
# (remote_FBKT pid=20624)  equal
# (remote_FBKT pid=20624)  t
# (remote_FBKT pid=20624) o
# (remote_FBKT pid=20624)  "t
# (remote_FBKT pid=20624) oo
# (remote_FBKT pid=20624) _ma
# (remote_FBKT pid=20624) n
# (remote_FBKT pid=20624) y
# (remote_FBKT pid=20624) _p
# (remote_FBKT pid=20624) i
# (remote_FBKT pid=20624) ng
# (remote_FBKT pid=20624) s"
# (remote_FBKT pid=37228) E1229 14:34:18.250000000 41684 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=31496) E1229 14:34:18.286000000 27468 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_ping
# (remote_FBKT pid=31496) s
# (remote_FBKT pid=31496) "
# (remote_FBKT pid=4832) E1229 14:34:18.215000000   816 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=13696) E1229 14:34:18.221000000 21972 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=43188) E1229 14:34:18.236000000 31620 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=32348) E1229 14:34:18.294000000 22704 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41336) E1229 14:34:18.276000000 30316 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=27036) E1229 14:34:18.243000000 43312 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=37052) E1229 14:34:18.223000000 21868 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=30636) E1229 14:34:18.272000000 19744 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=31596) E1229 14:34:18.262000000 28328 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=38704) E1229 14:34:18.232000000 28308 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=33108) E1229 14:34:18.273000000 21552 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=26036) E1229 14:34:18.292000000 23012 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=19556) E1229 14:34:18.224000000 20708 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41804) E1229 14:34:18.278000000 36732 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=26520) E1229 14:34:18.288000000 45408 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=39400) E1229 14:34:18.205000000 20520 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=13200) E1229 14:34:18.209000000 35836 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=39768) E1229 14:34:18.259000000  2324 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=9416) E1229 14:34:18.203000000 37832 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=22296) E1229 14:34:18.278000000 27628 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=45580) E1229 14:34:18.275000000 17988 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=32888) E1229 14:34:18.210000000 37544 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=5088) E1229 14:34:18.259000000 26668 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=22740) E1229 14:34:18.289000000 21448 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41440) E1229 14:34:18.234000000 23792 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=15132) E1229 14:34:18.208000000 41456 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=4612) E1229 14:34:18.211000000 29404 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=28852) E1229 14:34:18.254000000 38184 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=30392) E1229 14:34:18.279000000 17744 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=45612) E1229 14:34:18.293000000 24184 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=30456) E1229 14:34:18.276000000  9588 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=17568) E1229 14:34:18.203000000 39560 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=8024) E1229 14:34:18.200000000 38932 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=2684) E1229 14:34:18.292000000 36956 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=43360) E1229 14:34:18.260000000 23348 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=43684) E1229 14:34:18.245000000 10456 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41900) E1229 14:34:18.284000000 18440 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=40836) E1229 14:34:18.275000000 40416 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=43716) E1229 14:34:18.274000000 21128 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=44196) E1229 14:34:18.231000000 25628 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=14532) E1229 14:34:18.260000000 45992 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=32228) E1229 14:34:18.229000000 42304 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=20876) E1229 14:34:18.298000000 16456 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41556) E1229 14:34:18.242000000 20752 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=45568) E1229 14:34:18.296000000 41748 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=46036) E1229 14:34:18.299000000 22728 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=14916) E1229 14:34:18.218000000 39032 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=45076) E1229 14:34:18.257000000 40844 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=16492) E1229 14:34:18.207000000 38960 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=45420) E1229 14:34:18.213000000 20564 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=41024) E1229 14:34:18.240000000 26748 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=23988) E1229 14:34:18.264000000 21964 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=27864) E1229 14:34:18.212000000 33956 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=20108) E1229 14:34:18.231000000 22240 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=25116) E1229 14:34:18.282000000 40800 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=42988) E1229 14:34:18.226000000  9700 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=34440) E1229 14:34:18.238000000 13024 src/core/ext/transport/chttp2/transport/chttp2_transport.cc:1103] Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (remote_FBKT pid=40596)  GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# Start to simulate... at Thu Dec 29 14:34:18 2022
# PCS:0.342, PGS:0.794
# Total time used: 170.0556399822235s, simulation ends at Thu Dec 29 14:37:08 2022
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:37:09 2022
# PCS:0.454, PGS:0.954
# Total time used: 171.7471148967743s, simulation ends at Thu Dec 29 14:39:59 2022
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:40:00 2022
# PCS:0.374, PGS:0.88
# Total time used: 259.83448100090027s, simulation ends at Thu Dec 29 14:44:19 2022
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:44:20 2022
# PCS:0.414, PGS:0.898
# Total time used: 251.61226296424866s, simulation ends at Thu Dec 29 14:48:31 2022
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:48:32 2022
# PCS:0.352, PGS:0.83
# Total time used: 280.73286271095276s, simulation ends at Thu Dec 29 14:53:12 2022
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:53:13 2022
# PCS:0.546, PGS:0.988
# Total time used: 282.89947986602783s, simulation ends at Thu Dec 29 14:57:55 2022
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 14:57:55 2022
# PCS:0.406, PGS:0.92
# Total time used: 526.8070623874664s, simulation ends at Thu Dec 29 15:06:41 2022
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 15:06:42 2022
# PCS:0.454, PGS:0.95
# Total time used: 530.5135610103607s, simulation ends at Thu Dec 29 15:15:32 2022
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 15:15:33 2022
# PCS:0.35, PGS:0.884
# Total time used: 558.8487641811371s, simulation ends at Thu Dec 29 15:24:51 2022
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 15:24:52 2022
# PCS:0.58, PGS:0.996
# Total time used: 561.5130932331085s, simulation ends at Thu Dec 29 15:34:12 2022
# Modified Sequential Halving
# --------New experiments with  k=3249----------------------
# Start to simulate... at Thu Dec 29 15:34:13 2022
# PCS:0.552, PGS:0.99
# Total time used: 253.2598819732666s, simulation ends at Thu Dec 29 15:38:26 2022
# problem size:11774
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 15:38:27 2022
# PCS:0.222, PGS:0.648
# Total time used: 568.7162132263184s, simulation ends at Thu Dec 29 15:47:55 2022
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 15:47:56 2022
# PCS:0.29, PGS:0.724
# Total time used: 584.7896485328674s, simulation ends at Thu Dec 29 15:57:39 2022
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 15:57:40 2022
# PCS:0.202, PGS:0.52
# Total time used: 605.3701496124268s, simulation ends at Thu Dec 29 16:07:45 2022
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 16:07:46 2022
# PCS:0.3, PGS:0.804
# Total time used: 609.4390888214111s, simulation ends at Thu Dec 29 16:17:54 2022
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 16:17:55 2022
# PCS:0.218, PGS:0.67
# Total time used: 949.3333134651184s, simulation ends at Thu Dec 29 16:33:44 2022
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 16:33:44 2022
# PCS:0.308, PGS:0.792
# Total time used: 921.6164910793304s, simulation ends at Thu Dec 29 16:49:05 2022
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 16:49:06 2022
# PCS:0.204, PGS:0.614
# Total time used: 1001.3806383609772s, simulation ends at Thu Dec 29 17:05:47 2022
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 17:05:48 2022
# PCS:0.396, PGS:0.89
# Total time used: 1005.3565473556519s, simulation ends at Thu Dec 29 17:22:32 2022
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 17:22:33 2022
# PCS:0.314, PGS:0.824
# Total time used: 1929.621299982071s, simulation ends at Thu Dec 29 17:54:42 2022
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 17:54:42 2022
# PCS:0.348, PGS:0.852
# Total time used: 1935.3762392997742s, simulation ends at Thu Dec 29 18:26:57 2022
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 18:26:58 2022
# PCS:0.238, PGS:0.616
# Total time used: 1997.0540699958801s, simulation ends at Thu Dec 29 19:00:14 2022
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 19:00:15 2022
# PCS:0.482, PGS:0.952
# Total time used: 1994.466594696045s, simulation ends at Thu Dec 29 19:33:28 2022
# Modified Sequential Halving
# --------New experiments with  k=11774----------------------
# Start to simulate... at Thu Dec 29 19:33:29 2022
# PCS:0.446, PGS:0.966
# Total time used: 1025.921557188034s, simulation ends at Thu Dec 29 19:50:34 2022
# problem size:57624
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Thu Dec 29 19:51:08 2022
# PCS:0.168, PGS:0.716
# Total time used: 2862.2909853458405s, simulation ends at Thu Dec 29 20:38:19 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Thu Dec 29 20:38:51 2022
# PCS:0.144, PGS:0.8
# Total time used: 2812.412262916565s, simulation ends at Thu Dec 29 21:25:11 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Thu Dec 29 21:25:47 2022
# PCS:0.14, PGS:0.694
# Total time used: 2866.6349382400513s, simulation ends at Thu Dec 29 22:12:58 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Thu Dec 29 22:13:33 2022
# PCS:0.192, PGS:0.9
# Total time used: 2961.4314818382263s, simulation ends at Thu Dec 29 23:02:19 2022
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Thu Dec 29 23:02:52 2022
# PCS:0.174, PGS:0.772
# Total time used: 4547.044864416122s, simulation ends at Fri Dec 30 00:18:06 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 00:18:39 2022
# PCS:0.158, PGS:0.804
# Total time used: 4387.201831579208s, simulation ends at Fri Dec 30 01:31:13 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 01:31:43 2022
# PCS:0.152, PGS:0.702
# Total time used: 4858.2787845134735s, simulation ends at Fri Dec 30 02:52:12 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 02:52:47 2022
# PCS:0.216, PGS:0.938
# Total time used: 4901.387176275253s, simulation ends at Fri Dec 30 04:13:53 2022
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 04:14:29 2022
# PCS:0.168, PGS:0.854
# Total time used: 9520.63584780693s, simulation ends at Fri Dec 30 06:52:34 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 06:53:10 2022
# PCS:0.202, PGS:0.884
# Total time used: 9473.600328683853s, simulation ends at Fri Dec 30 09:30:27 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 09:31:03 2022
# PCS:0.172, PGS:0.772
# Total time used: 9914.356418132782s, simulation ends at Fri Dec 30 12:15:42 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 12:16:16 2022
# PCS:0.244, PGS:0.978
# Total time used: 9910.855292081833s, simulation ends at Fri Dec 30 15:00:53 2022
# Modified Sequential Halving
# --------New experiments with  k=57624----------------------
# Start to simulate... at Fri Dec 30 15:01:26 2022
# PCS:0.272, PGS:0.99
# Total time used: 5670.53848028183s, simulation ends at Fri Dec 30 16:35:23 2022

# %%
FBKT_results, FBKTS_results, EFG_results, EFGPlus_results, MoSH_results
# Out:
# ([[0.326, 0.798],
#   [0.374, 0.88],
#   [0.406, 0.92],
#   [0.222, 0.648],
#   [0.218, 0.67],
#   [0.314, 0.824],
#   [0.168, 0.716],
#   [0.174, 0.772],
#   [0.168, 0.854]],
#  [[0.362, 0.852],
#   [0.414, 0.898],
#   [0.454, 0.95],
#   [0.29, 0.724],
#   [0.308, 0.792],
#   [0.348, 0.852],
#   [0.144, 0.8],
#   [0.158, 0.804],
#   [0.202, 0.884]],
#  [[0.342, 0.794],
#   [0.352, 0.83],
#   [0.35, 0.884],
#   [0.202, 0.52],
#   [0.204, 0.614],
#   [0.238, 0.616],
#   [0.14, 0.694],
#   [0.152, 0.702],
#   [0.172, 0.772]],
#  [[0.454, 0.954],
#   [0.546, 0.988],
#   [0.58, 0.996],
#   [0.3, 0.804],
#   [0.396, 0.89],
#   [0.482, 0.952],
#   [0.192, 0.9],
#   [0.216, 0.938],
#   [0.244, 0.978]],
#  [[0.552, 0.99], [0.446, 0.966], [0.272, 0.99]])
