# %%
import numpy as np
import matplotlib.pyplot as plt

import ray
import time

from utils import *
from procedures import *
# https://albertcthomas.github.io/good-practices-random-number-generators/

# plt.rcParams["font.sans-serif"] = "Arial Unicode MS"
plt.rcParams["font.sans-serif"] = "DejaVu Sans"
# plt.rcParams["axes.unicode_minus"] = False
# mlib.rc('xtick', labelsize=15) 
# mlib.rc('ytick', labelsize=15) 
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# 2022-12-24 22:42:02,510	INFO services.py:1274 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '10.192.9.221',
#  'raylet_ip_address': '10.192.9.221',
#  'redis_address': '10.192.9.221:6379',
#  'object_store_address': 'tcp://127.0.0.1:62331',
#  'raylet_socket_name': 'tcp://127.0.0.1:61270',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ray\\session_2022-12-24_22-41-57_272818_29436',
#  'metrics_export_port': 57544,
#  'node_id': 'bf843089bcc67573e9dfadc5f041875d632ae04888a087512dbeb13a'}

# %%
seed = 20221224
np.random.seed(seed)
n_replications =1000

min_power = 13
max_power = 13
base = 2

gamma = 0.1
var = 1
lamda = -1.5
varlow = 1
varhigh = 2

rng = np.random.default_rng(seed)

# %%
power = 13
base = 2
ratios = [0.8]
ns = [100, 200, 300, 400, 500, 600, 700, 800]
n_replications = 1000

# %%
SCCV_results = []
EMCV_results = []
EMIV_results = []
EMDV_results = []

results_collection = [SCCV_results,EMCV_results, EMIV_results, EMDV_results]

SCCVgenerators =  [SCCVGenerator(base**power, gamma, var) for i in range(n_replications)]
EMCVgenerators =   [EMCVGenerator(base**power, gamma, lamda, var) for i in range(n_replications)]
EMIVgenerators =  [EMIVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]
EMDVgenerators =  [EMDVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]

generator_types = [SCCVgenerators, EMCVgenerators,  EMIVgenerators, EMDVgenerators]

for i, generators in enumerate(generator_types):
    print("----------------------------------Generator Type {}--------------------------------".format(i))
    for n in ns:
        print("----------------------------------n {}--------------------------------".format(n))
        for ratio in ratios:
            print("----------------------------------Exploration Ratio {}--------------------------------".format(ratio))
            n0 = np.int32(n * ratio)
            ng = n - n0
            PCS, PGS = parallel_experiments(rng, generators, policy=EFG, remote_policy=remote_EFG, args={"n0":n0, "ng":ng})
            results_collection[i].append(PCS)
# Out:
# ----------------------------------Generator Type 0--------------------------------
# ----------------------------------n 100--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:44:56 2022
# PCS:0.166, PGS:0.166
# Total time used: 59.396976709365845s, simulation ends at Sat Dec 24 22:45:54 2022
# ----------------------------------n 200--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:45:56 2022
# PCS:0.46, PGS:0.46
# Total time used: 115.77904725074768s, simulation ends at Sat Dec 24 22:47:50 2022
# ----------------------------------n 300--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:47:51 2022
# PCS:0.631, PGS:0.631
# Total time used: 172.25182509422302s, simulation ends at Sat Dec 24 22:50:42 2022
# ----------------------------------n 400--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:50:44 2022
# PCS:0.768, PGS:0.768
# Total time used: 227.46986031532288s, simulation ends at Sat Dec 24 22:54:29 2022
# ----------------------------------n 500--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:54:31 2022
# PCS:0.856, PGS:0.856
# Total time used: 282.6222367286682s, simulation ends at Sat Dec 24 22:59:12 2022
# ----------------------------------n 600--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 22:59:14 2022
# PCS:0.885, PGS:0.885
# Total time used: 336.80545568466187s, simulation ends at Sat Dec 24 23:04:49 2022
# ----------------------------------n 700--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:04:50 2022
# PCS:0.93, PGS:0.93
# Total time used: 393.6303060054779s, simulation ends at Sat Dec 24 23:11:22 2022
# ----------------------------------n 800--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:11:24 2022
# PCS:0.935, PGS:0.935
# Total time used: 446.93169021606445s, simulation ends at Sat Dec 24 23:18:49 2022
# ----------------------------------Generator Type 1--------------------------------
# ----------------------------------n 100--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:18:51 2022
# PCS:0.702, PGS:0.702
# Total time used: 58.32882022857666s, simulation ends at Sat Dec 24 23:19:48 2022
# ----------------------------------n 200--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:19:49 2022
# PCS:0.838, PGS:0.838
# Total time used: 113.42715048789978s, simulation ends at Sat Dec 24 23:21:41 2022
# ----------------------------------n 300--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:21:43 2022
# PCS:0.897, PGS:0.897
# Total time used: 170.7464418411255s, simulation ends at Sat Dec 24 23:24:32 2022
# ----------------------------------n 400--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:24:33 2022
# PCS:0.939, PGS:0.939
# Total time used: 223.69485664367676s, simulation ends at Sat Dec 24 23:28:15 2022
# ----------------------------------n 500--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:28:17 2022
# PCS:0.966, PGS:0.966
# Total time used: 279.9302113056183s, simulation ends at Sat Dec 24 23:32:55 2022
# ----------------------------------n 600--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:32:57 2022
# PCS:0.977, PGS:0.977
# Total time used: 337.044775724411s, simulation ends at Sat Dec 24 23:38:32 2022
# ----------------------------------n 700--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:38:34 2022
# PCS:0.992, PGS:0.992
# Total time used: 459.0202600955963s, simulation ends at Sat Dec 24 23:46:11 2022
# ----------------------------------n 800--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:46:14 2022
# PCS:0.989, PGS:0.989
# Total time used: 495.0238790512085s, simulation ends at Sat Dec 24 23:54:26 2022
# ----------------------------------Generator Type 2--------------------------------
# ----------------------------------n 100--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:54:29 2022
# PCS:0.674, PGS:0.674
# Total time used: 69.59046459197998s, simulation ends at Sat Dec 24 23:55:36 2022
# ----------------------------------n 200--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:55:38 2022
# PCS:0.83, PGS:0.83
# Total time used: 120.72016787528992s, simulation ends at Sat Dec 24 23:57:37 2022
# ----------------------------------n 300--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 24 23:57:39 2022
# PCS:0.887, PGS:0.887
# Total time used: 184.108726978302s, simulation ends at Sun Dec 25 00:00:41 2022
# ----------------------------------n 400--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:00:43 2022
# PCS:0.945, PGS:0.945
# Total time used: 263.6020812988281s, simulation ends at Sun Dec 25 00:05:04 2022
# ----------------------------------n 500--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:05:07 2022
# PCS:0.963, PGS:0.963
# Total time used: 328.7585551738739s, simulation ends at Sun Dec 25 00:10:33 2022
# ----------------------------------n 600--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:10:35 2022
# PCS:0.976, PGS:0.976
# Total time used: 397.62364888191223s, simulation ends at Sun Dec 25 00:17:11 2022
# ----------------------------------n 700--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:17:13 2022
# PCS:0.985, PGS:0.985
# Total time used: 455.1531047821045s, simulation ends at Sun Dec 25 00:24:46 2022
# ----------------------------------n 800--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:24:48 2022
# PCS:0.995, PGS:0.995
# Total time used: 521.1251418590546s, simulation ends at Sun Dec 25 00:33:27 2022
# ----------------------------------Generator Type 3--------------------------------
# ----------------------------------n 100--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:33:29 2022
# PCS:0.526, PGS:0.526
# Total time used: 69.11320495605469s, simulation ends at Sun Dec 25 00:34:36 2022
# ----------------------------------n 200--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:34:38 2022
# PCS:0.712, PGS:0.712
# Total time used: 134.48875737190247s, simulation ends at Sun Dec 25 00:36:51 2022
# ----------------------------------n 300--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:36:53 2022
# PCS:0.766, PGS:0.766
# Total time used: 199.59250450134277s, simulation ends at Sun Dec 25 00:40:10 2022
# ----------------------------------n 400--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:40:12 2022
# PCS:0.821, PGS:0.821
# Total time used: 263.59594798088074s, simulation ends at Sun Dec 25 00:44:34 2022
# ----------------------------------n 500--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:44:36 2022
# PCS:0.872, PGS:0.872
# Total time used: 328.4056222438812s, simulation ends at Sun Dec 25 00:50:02 2022
# ----------------------------------n 600--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:50:04 2022
# PCS:0.898, PGS:0.898
# Total time used: 392.75203943252563s, simulation ends at Sun Dec 25 00:56:35 2022
# ----------------------------------n 700--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 00:56:37 2022
# PCS:0.914, PGS:0.914
# Total time used: 457.43637561798096s, simulation ends at Sun Dec 25 01:04:13 2022
# ----------------------------------n 800--------------------------------
# ----------------------------------Exploration Ratio 0.8--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 01:04:15 2022
# PCS:0.922, PGS:0.922
# Total time used: 522.1638548374176s, simulation ends at Sun Dec 25 01:12:55 2022

# %%
GSCCV_results = []
GEMCV_results = []
GEMIV_results = []
GEMDV_results = []

Gresults_collection = [GSCCV_results,GEMCV_results, GEMIV_results, GEMDV_results]

for i, generators in enumerate(generator_types):
    print("----------------------------------Generator Type: {}--------------------------------".format(i))
    for n in ns:
        print("----------------------------------n: {}--------------------------------".format(n))
        n0 = 1
        ng = n - n0
        PCS, PGS = parallel_experiments(rng, generators, policy=EFG, remote_policy=remote_EFG, args={"n0":n0, "ng":ng})
        Gresults_collection[i].append(PCS)
# Out:
# ----------------------------------Generator Type: 0--------------------------------
# ----------------------------------n: 100--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 01:12:56 2022
# PCS:0.121, PGS:0.121
# Total time used: 320.7729961872101s, simulation ends at Sun Dec 25 01:18:15 2022
# ----------------------------------n: 200--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 01:18:17 2022
# PCS:0.132, PGS:0.132
# Total time used: 640.4464557170868s, simulation ends at Sun Dec 25 01:28:56 2022
# ----------------------------------n: 300--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 01:28:58 2022
# PCS:0.128, PGS:0.128
# Total time used: 960.6286451816559s, simulation ends at Sun Dec 25 01:44:57 2022
# ----------------------------------n: 400--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 01:44:58 2022
# PCS:0.132, PGS:0.132
# Total time used: 1280.4494500160217s, simulation ends at Sun Dec 25 02:06:17 2022
# ----------------------------------n: 500--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 02:06:19 2022
# PCS:0.121, PGS:0.121
# Total time used: 1607.1528768539429s, simulation ends at Sun Dec 25 02:33:04 2022
# ----------------------------------n: 600--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 02:33:06 2022
# PCS:0.137, PGS:0.137
# Total time used: 1948.3336837291718s, simulation ends at Sun Dec 25 03:05:32 2022
# ----------------------------------n: 700--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 03:05:34 2022
# PCS:0.13, PGS:0.13
# Total time used: 2307.691479206085s, simulation ends at Sun Dec 25 03:44:00 2022
# ----------------------------------n: 800--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 03:44:02 2022
# PCS:0.154, PGS:0.154
# Total time used: 2591.5026824474335s, simulation ends at Sun Dec 25 04:27:12 2022
# ----------------------------------Generator Type: 1--------------------------------
# ----------------------------------n: 100--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 04:27:13 2022
# PCS:0.151, PGS:0.151
# Total time used: 328.2114522457123s, simulation ends at Sun Dec 25 04:32:40 2022
# ----------------------------------n: 200--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 04:32:42 2022
# PCS:0.144, PGS:0.144
# Total time used: 646.6874895095825s, simulation ends at Sun Dec 25 04:43:27 2022
# ----------------------------------n: 300--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 04:43:28 2022
# PCS:0.129, PGS:0.129
# Total time used: 986.8152704238892s, simulation ends at Sun Dec 25 04:59:53 2022
# ----------------------------------n: 400--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 04:59:55 2022
# PCS:0.147, PGS:0.147
# Total time used: 1323.8415412902832s, simulation ends at Sun Dec 25 05:21:57 2022
# ----------------------------------n: 500--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 05:21:59 2022
# PCS:0.141, PGS:0.141
# Total time used: 1652.6286244392395s, simulation ends at Sun Dec 25 05:49:30 2022
# ----------------------------------n: 600--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 05:49:31 2022
# PCS:0.158, PGS:0.158
# Total time used: 1959.1556873321533s, simulation ends at Sun Dec 25 06:22:09 2022
# ----------------------------------n: 700--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 06:22:11 2022
# PCS:0.149, PGS:0.149
# Total time used: 2325.336531162262s, simulation ends at Sun Dec 25 07:00:54 2022
# ----------------------------------n: 800--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 07:00:56 2022
# PCS:0.159, PGS:0.159
# Total time used: 2608.921976327896s, simulation ends at Sun Dec 25 07:44:23 2022
# ----------------------------------Generator Type: 2--------------------------------
# ----------------------------------n: 100--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 07:44:25 2022
# PCS:0.136, PGS:0.136
# Total time used: 324.53721380233765s, simulation ends at Sun Dec 25 07:49:48 2022
# ----------------------------------n: 200--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 07:49:49 2022
# PCS:0.169, PGS:0.169
# Total time used: 651.4445152282715s, simulation ends at Sun Dec 25 08:00:39 2022
# ----------------------------------n: 300--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 08:00:41 2022
# PCS:0.137, PGS:0.137
# Total time used: 994.2590973377228s, simulation ends at Sun Dec 25 08:17:14 2022
# ----------------------------------n: 400--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 08:17:15 2022
# PCS:0.158, PGS:0.158
# Total time used: 1317.9880545139313s, simulation ends at Sun Dec 25 08:39:12 2022
# ----------------------------------n: 500--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 08:39:13 2022
# PCS:0.158, PGS:0.158
# Total time used: 1664.3947956562042s, simulation ends at Sun Dec 25 09:06:56 2022
# ----------------------------------n: 600--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 09:06:58 2022
# PCS:0.163, PGS:0.163
# Total time used: 1992.6427290439606s, simulation ends at Sun Dec 25 09:40:09 2022
# ----------------------------------n: 700--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 09:40:11 2022
# PCS:0.154, PGS:0.154
# Total time used: 2361.6436393260956s, simulation ends at Sun Dec 25 10:19:30 2022
# ----------------------------------n: 800--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 10:19:32 2022
# PCS:0.119, PGS:0.119
# Total time used: 2638.996727705002s, simulation ends at Sun Dec 25 11:03:29 2022
# ----------------------------------Generator Type: 3--------------------------------
# ----------------------------------n: 100--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 11:03:31 2022
# PCS:0.1, PGS:0.1
# Total time used: 326.1722695827484s, simulation ends at Sun Dec 25 11:08:55 2022
# ----------------------------------n: 200--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 11:08:57 2022
# PCS:0.105, PGS:0.105
# Total time used: 659.0470879077911s, simulation ends at Sun Dec 25 11:19:54 2022
# ----------------------------------n: 300--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 11:19:56 2022
# PCS:0.099, PGS:0.099
# Total time used: 993.3993413448334s, simulation ends at Sun Dec 25 11:36:28 2022
# ----------------------------------n: 400--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 11:36:30 2022
# PCS:0.107, PGS:0.107
# Total time used: 1346.5482294559479s, simulation ends at Sun Dec 25 11:58:54 2022
# ----------------------------------n: 500--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 11:58:56 2022
# PCS:0.111, PGS:0.111
# Total time used: 1657.785441160202s, simulation ends at Sun Dec 25 12:26:32 2022
# ----------------------------------n: 600--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 12:26:34 2022
# PCS:0.117, PGS:0.117
# Total time used: 1957.772013425827s, simulation ends at Sun Dec 25 12:59:10 2022
# ----------------------------------n: 700--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 12:59:12 2022
# PCS:0.115, PGS:0.115
# Total time used: 2290.6550743579865s, simulation ends at Sun Dec 25 13:37:21 2022
# ----------------------------------n: 800--------------------------------
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 25 13:37:22 2022
# PCS:0.119, PGS:0.119
# Total time used: 2597.1871078014374s, simulation ends at Sun Dec 25 14:20:38 2022

# %%
results_collection
# Out:
# [[0.166, 0.46, 0.631, 0.768, 0.856, 0.885, 0.93, 0.935],
#  [0.702, 0.838, 0.897, 0.939, 0.966, 0.977, 0.992, 0.989],
#  [0.674, 0.83, 0.887, 0.945, 0.963, 0.976, 0.985, 0.995],
#  [0.526, 0.712, 0.766, 0.821, 0.872, 0.898, 0.914, 0.922]]

# %%
Gresults_collection
# Out:
# [[0.121, 0.132, 0.128, 0.132, 0.121, 0.137, 0.13, 0.154],
#  [0.151, 0.144, 0.129, 0.147, 0.141, 0.158, 0.149, 0.159],
#  [0.136, 0.169, 0.137, 0.158, 0.158, 0.163, 0.154, 0.119],
#  [0.1, 0.105, 0.099, 0.107, 0.111, 0.117, 0.115, 0.119]]
