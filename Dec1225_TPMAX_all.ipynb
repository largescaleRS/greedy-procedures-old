# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *
# https://albertcthomas.github.io/good-practices-random-number-generators/
# plt.rcParams["font.sans-serif"] = "Arial Unicode MS"
plt.rcParams["font.sans-serif"] = "DejaVu Sans"
# plt.rcParams["axes.unicode_minus"] = False
# mlib.rc('xtick', labelsize=15) 
# mlib.rc('ytick', labelsize=15) |
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# RayContext(dashboard_url='', python_version='3.8.0', ray_version='1.13.0', ray_commit='e4ce38d001dbbe09cd21c497fedd03d692b2be3e', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:58840', 'raylet_socket_name': 'tcp://127.0.0.1:60797', 'webui_url': '', 'session_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ray\\session_2022-12-25_22-50-25_609904_13184', 'metrics_export_port': 60777, 'gcs_address': '127.0.0.1:62784', 'address': '127.0.0.1:62784', 'node_id': 'e6aeca3b4f4f56b7534e544fe649a93073e4177a0451c7933329ced7'})

# %%
from TpMaxSimulator import TpMaxSimulator

# %%
problem_types = [20, 30]

recipes0 = [30, 50, 100, 200]
recipes1 = [(2, 28), (4, 44), (9, 91),  (18, 182)]
recipes2 = [(27, 3), (45, 5), (90, 10), (180, 20)]
recipes3 = [(6, 21, 3), (10, 35, 5), (20, 70, 10), (40, 140, 20)]
recipes4 = [30, 50, 100, 200]
n_recipe = 4
G = 10
n_replications = 200
seed = 202212252251
_njobs, _nstages, _burnin = 2050, 3, 2000

# %%
rng = np.random.default_rng(seed)
FBKT_results = []
FBKTS_results = []
EFG_results = []
EFGPlus_results = []
MoSH_results = []

# %%
for problem_type in problem_types:
    slns, means = loadTrue(problem_type)
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
        
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:3249
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Sun Dec 25 22:52:14 2022
# PCS:0.32, PGS:0.825
# Total time used: 62.70059299468994s, simulation ends at Sun Dec 25 22:53:17 2022
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Sun Dec 25 22:53:17 2022
# PCS:0.38, PGS:0.89
# Total time used: 64.52002096176147s, simulation ends at Sun Dec 25 22:54:21 2022
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Sun Dec 25 22:54:21 2022
# PCS:0.29, PGS:0.765
# Total time used: 68.55101895332336s, simulation ends at Sun Dec 25 22:55:30 2022
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Sun Dec 25
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 00:36:51 2022
# PCS:0.36, PGS:0.815
# Total time used: 798.3466143608093s, simulation ends at Mon Dec 26 00:50:09 2022
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 00:50:10 2022
# PCS:0.39, PGS:0.89
# Total time used: 795.6224882602692s, simulation ends at Mon Dec 26 01:03:25 2022
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 01:03:25 2022
# PCS:0.22, PGS:0.685
# Total time used: 836.2459425926208s, simulation ends at Mon Dec 26 01:17:21 2022
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 01:17:22 2022
# PCS:0.415, PGS:0.935
# Total time used: 840.3038306236267s, simulation ends at Mon Dec 26 01:31:21 2022
# Modified Sequential Halving
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 01:31:22 2022
# PCS:0.52, PGS:0.965
# Total time used: 422.9910593032837s, simulation ends at Mon Dec 26 01:38:24 2022
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 01:38:25 2022
# PCS:0.365, PGS:0.83
# Total time used: 1623.4669811725616s, simulation ends at Mon Dec 26 02:05:28 2022
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 02:05:28 2022
# PCS:0.48, PGS:0.94
# Total time used: 1615.1961014270782s, simulation ends at Mon Dec 26 02:32:23 2022
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 02:32:23 2022
# PCS:0.255, PGS:0.695
# Total time used: 1651.3142576217651s, simulation ends at Mon Dec 26 02:59:54 2022
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 02:59:55 2022
# PCS:0.435, PGS:0.98
# Total time used: 1657.5183017253876s, simulation ends at Mon Dec 26 03:27:32 2022
# Modified Sequential Halving
# --------New experiments with  k=11774----------------------
# Start to simulate... at Mon Dec 26 03:27:32 2022
# PCS:0.575, PGS:1.0
# Total time used: 846.9952533245087s, simulation ends at Mon Dec 26 03:41:39 2022

# %%
FBKT_results, FBKTS_results, EFG_results, EFGPlus_results, MoSH_results
# Out:
# ([[0.32, 0.825],
#   [0.415, 0.885],
#   [0.44, 0.935],
#   [0.4, 0.95],
#   [0.24, 0.6],
#   [0.31, 0.72],
#   [0.36, 0.815],
#   [0.365, 0.83]],
#  [[0.38, 0.89],
#   [0.465, 0.905],
#   [0.4, 0.98],
#   [0.52, 0.98],
#   [0.29, 0.75],
#   [0.275, 0.755],
#   [0.39, 0.89],
#   [0.48, 0.94]],
#  [[0.29, 0.765],
#   [0.345, 0.835],
#   [0.405, 0.885],
#   [0.455, 0.93],
#   [0.18, 0.53],
#   [0.18, 0.57],
#   [0.22, 0.685],
#   [0.255, 0.695]],
#  [[0.445, 0.945],
#   [0.45, 0.97],
#   [0.535, 0.995],
#   [0.695, 1.0],
#   [0.3, 0.805],
#   [0.395, 0.895],
#   [0.415, 0.935],
#   [0.435, 0.98]],
#  [[0.605, 1.0], [0.61, 1.0], [0.52, 0.965], [0.575, 1.0]])

# %%
problem_types = [50]

# %%
seed = 202212260000
rng = np.random.default_rng(seed)

# %%
for problem_type in problem_types:
    slns, means = loadTrue(problem_type)
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
        
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:57624
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 03:41:47 2022
# PCS:0.125, PGS:0.725
# Total time used: 1145.968059539795s, simulation ends at Mon Dec 26 04:00:46 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 04:00:51 2022
# PCS:0.165, PGS:0.775
# Total time used: 1188.9112448692322s, simulation ends at Mon Dec 26 04:20:35 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 04:20:38 2022
# PCS:0.13, PGS:0.72
# Total time used: 1245.1982173919678s, simulation ends at Mon Dec 26 04:41:20 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 04:41:28 2022
# PCS:0.23, PGS:0.885
# Total time used: 1253.0113224983215s, simulation ends at Mon Dec 26 05:02:13 2022
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 05:02:20 2022
# PCS:0.215, PGS:0.84
# Total time used: 1943.8462834358215s, simulation ends at Mon Dec 26 05:34:37 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 05:34:44 2022
# PCS:0.245, PGS:0.855
# Total time used: 1866.536127090454s, simulation ends at Mon Dec 26 06:05:43 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 06:05:51 2022
# PCS:0.14, PGS:0.75
# Total time used: 2068.343547105789s, simulation ends at Mon Dec 26 06:40:12 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 06:40:19 2022
# PCS:0.235, PGS:0.945
# Total time used: 2060.89768743515s, simulation ends at Mon Dec 26 07:14:32 2022
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 07:14:40 2022
# PCS:0.165, PGS:0.84
# Total time used: 3928.259577512741s, simulation ends at Mon Dec 26 08:20:01 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 08:20:09 2022
# PCS:0.2, PGS:0.9
# Total time used: 3932.176149368286s, simulation ends at Mon Dec 26 09:25:33 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 09:25:41 2022
# PCS:0.15, PGS:0.74
# Total time used: 4063.3966505527496s, simulation ends at Mon Dec 26 10:33:16 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 10:33:24 2022
# PCS:0.26, PGS:0.96
# Total time used: 4071.8975853919983s, simulation ends at Mon Dec 26 11:41:08 2022
# Modified Sequential Halving
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 11:41:16 2022
# PCS:0.305, PGS:0.985
# Total time used: 2350.323095560074s, simulation ends at Mon Dec 26 12:20:18 2022
# FBKT
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 12:20:26 2022
# PCS:0.185, PGS:0.925
# Total time used: 7858.515748023987s, simulation ends at Mon Dec 26 14:31:17 2022
# FBKTSeeding
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 14:31:26 2022
# PCS:0.225, PGS:0.925
# Total time used: 7861.028180360794s, simulation ends at Mon Dec 26 16:42:18 2022
# EFG
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 16:42:25 2022
# PCS:0.155, PGS:0.825
# Total time used: 8130.730703830719s, simulation ends at Mon Dec 26 18:57:49 2022
# EFGPlus
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 18:57:55 2022
# PCS:0.245, PGS:1.0
# Total time used: 8181.016882658005s, simulation ends at Mon Dec 26 21:14:10 2022
# Modified Sequential Halving
# --------New experiments with  k=57624----------------------
# Start to simulate... at Mon Dec 26 21:14:17 2022
# PCS:0.29, PGS:1.0
# Total time used: 4653.072303056717s, simulation ends at Mon Dec 26 22:31:43 2022
