# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *
# https://albertcthomas.github.io/good-practices-random-number-generators/
# plt.rcParams["font.sans-serif"] = "Arial Unicode MS"
plt.rcParams["font.sans-serif"] = "DejaVu Sans"
# plt.rcParams["axes.unicode_minus"] = False
# mlib.rc('xtick', labelsize=15) 
# mlib.rc('ytick', labelsize=15) |
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# 2022-12-18 23:39:56,453	INFO services.py:1274 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '10.192.9.221',
#  'raylet_ip_address': '10.192.9.221',
#  'redis_address': '10.192.9.221:6379',
#  'object_store_address': 'tcp://127.0.0.1:62893',
#  'raylet_socket_name': 'tcp://127.0.0.1:60592',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ray\\session_2022-12-18_23-39-50_474551_27472',
#  'metrics_export_port': 65192,
#  'node_id': '7d9458abc3c77e619ac7fb43bc6e17883c13781127d95883b10cf43a'}

# %%
seed = 20221219
np.random.seed(seed)
n_replications = 1000

power = 13
base = 2

gamma = 0.1
var = 1
lamda = -1
varlow = 1
varhigh = 2

n = 200
rng = np.random.default_rng(seed)

# %%
EFG_results = []
ratios = [0.  , 0.2 , 0.35, 0.45, 0.5 , 0.55, 0.6 , 0.64, 0.68, 0.72, 0.76,
       0.79, 0.82, 0.85, 0.88, 0.9 , 0.92, 0.94, 0.96, 0.98, 1.  ]

for ratio in ratios:
    print("The allocated ratio is {}".format(ratio))
    SCCVgenerators =  [SCCVGenerator(base**power, gamma, var) for i in range(n_replications)]
    EMCVgenerators =   [EMCVGenerator(base**power, gamma, lamda, var) for i in range(n_replications)]
    EMIVgenerators =  [EMIVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]
    EMDVgenerators =  [EMDVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]
    generator_types = [SCCVgenerators, EMCVgenerators,  EMIVgenerators, EMDVgenerators]
    for i, generators in enumerate(generator_types):
        print("----------------------------------Generator Type {}--------------------------------".format(i))
        n0 = np.int32(n*ratio)
        if n0 == 0:
            n0 = 1
        ng = n-n0
        print("EFG")
        PCS, PGS = parallel_experiments(rng, generators, policy=EFG, remote_policy=remote_EFG, args={"n0":n0, "ng":ng})
        EFG_results.append(PCS)
print(EFG_results)
# Out:
# The allocated ratio is 0.0
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 18 23:48:24 2022
# PCS:0.131, PGS:0.131
# Total time used: 695.3104066848755s, simulation ends at Sun Dec 18 23:59:58 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sun Dec 18 23:59:59 2022
# PCS:0.158, PGS:0.158
# Total time used: 700.9427735805511s, simulation ends at Mon Dec 19 00:11:38 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 00:11:40 2022
# PCS:0.15, PGS:0.15
# Total time used: 703.1597630977631s, simulation ends at Mon Dec 19 00:23:22 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 00:23:23 2022
# PCS:0.101, PGS:0.101
# Total time used: 706.0449025630951s, simulation ends at Mon Dec 19 00:35:08 2022
# The allocated ratio is 0.2
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 00:35:11 2022
# PCS:0.442, PGS:0.442
# Total time used: 557.7035553455353s, simulation ends at Mon Dec 19 00:44:26 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 00:44:29 2022
# PCS:0.498, PGS:0.498
# Total time used: 555.1213173866272s, simulation ends at Mon Dec 19 00:53:41 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 00:53:43 2022
# PCS:0.521, PGS:0.521
# Total time used: 556.4691200256348s, simulation ends at Mon Dec 19 01:02:58 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:03:00 2022
# PCS:0.394, PGS:0.394
# Total time used: 565.1332247257233s, simulation ends at Mon Dec 19 01:12:23 2022
# The allocated ratio is 0.35
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:12:26 2022
# PCS:0.51, PGS:0.51
# Total time used: 452.8702747821808s, simulation ends at Mon Dec 19 01:19:57 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:19:59 2022
# PCS:0.632, PGS:0.632
# Total time used: 454.84093165397644s, simulation ends at Mon Dec 19 01:27:32 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:27:34 2022
# PCS:0.629, PGS:0.629
# Total time used: 451.31036376953125s, simulation ends at Mon Dec 19 01:35:03 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:35:05 2022
# PCS:0.466, PGS:0.466
# Total time used: 456.474586725235s, simulation ends at Mon Dec 19 01:42:39 2022
# The allocated ratio is 0.45
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:42:42 2022
# PCS:0.56, PGS:0.56
# Total time used: 384.1575779914856s, simulation ends at Mon Dec 19 01:49:04 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:49:06 2022
# PCS:0.685, PGS:0.685
# Total time used: 382.5750217437744s, simulation ends at Mon Dec 19 01:55:27 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 01:55:29 2022
# PCS:0.716, PGS:0.716
# Total time used: 386.6601104736328s, simulation ends at Mon Dec 19 02:01:54 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:01:56 2022
# PCS:0.567, PGS:0.567
# Total time used: 388.0661561489105s, simulation ends at Mon Dec 19 02:08:22 2022
# The allocated ratio is 0.5
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:08:25 2022
# PCS:0.546, PGS:0.546
# Total time used: 351.4675452709198s, simulation ends at Mon Dec 19 02:14:14 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:14:16 2022
# PCS:0.744, PGS:0.744
# Total time used: 350.4040491580963s, simulation ends at Mon Dec 19 02:20:04 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:20:06 2022
# PCS:0.704, PGS:0.704
# Total time used: 352.950621843338s, simulation ends at Mon Dec 19 02:25:57 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:25:59 2022
# PCS:0.571, PGS:0.571
# Total time used: 357.87537956237793s, simulation ends at Mon Dec 19 02:31:55 2022
# The allocated ratio is 0.55
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:31:58 2022
# PCS:0.547, PGS:0.547
# Total time used: 319.9202947616577s, simulation ends at Mon Dec 19 02:37:16 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:37:18 2022
# PCS:0.756, PGS:0.756
# Total time used: 313.5138442516327s, simulation ends at Mon Dec 19 02:42:30 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:42:32 2022
# PCS:0.762, PGS:0.762
# Total time used: 314.5363712310791s, simulation ends at Mon Dec 19 02:47:44 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:47:46 2022
# PCS:0.59, PGS:0.59
# Total time used: 318.4978971481323s, simulation ends at Mon Dec 19 02:53:03 2022
# The allocated ratio is 0.6
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:53:06 2022
# PCS:0.547, PGS:0.547
# Total time used: 281.7400140762329s, simulation ends at Mon Dec 19 02:57:45 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 02:57:47 2022
# PCS:0.762, PGS:0.762
# Total time used: 278.3212947845459s, simulation ends at Mon Dec 19 03:02:24 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:02:26 2022
# PCS:0.775, PGS:0.775
# Total time used: 280.4798684120178s, simulation ends at Mon Dec 19 03:07:04 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:07:06 2022
# PCS:0.611, PGS:0.611
# Total time used: 279.98254323005676s, simulation ends at Mon Dec 19 03:11:44 2022
# The allocated ratio is 0.64
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:11:47 2022
# PCS:0.533, PGS:0.533
# Total time used: 251.22057962417603s, simulation ends at Mon Dec 19 03:15:56 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:15:58 2022
# PCS:0.77, PGS:0.77
# Total time used: 249.67833280563354s, simulation ends at Mon Dec 19 03:20:06 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:20:08 2022
# PCS:0.796, PGS:0.796
# Total time used: 250.22781896591187s, simulation ends at Mon Dec 19 03:24:16 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:24:18 2022
# PCS:0.638, PGS:0.638
# Total time used: 252.40296244621277s, simulation ends at Mon Dec 19 03:28:29 2022
# The allocated ratio is 0.68
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:28:32 2022
# PCS:0.512, PGS:0.512
# Total time used: 224.645201921463s, simulation ends at Mon Dec 19 03:32:14 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:32:16 2022
# PCS:0.783, PGS:0.783
# Total time used: 223.83851289749146s, simulation ends at Mon Dec 19 03:35:58 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:36:00 2022
# PCS:0.786, PGS:0.786
# Total time used: 222.99243640899658s, simulation ends at Mon Dec 19 03:39:41 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:39:43 2022
# PCS:0.614, PGS:0.614
# Total time used: 224.5882601737976s, simulation ends at Mon Dec 19 03:43:26 2022
# The allocated ratio is 0.72
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:43:29 2022
# PCS:0.504, PGS:0.504
# Total time used: 196.70384168624878s, simulation ends at Mon Dec 19 03:46:43 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:46:45 2022
# PCS:0.792, PGS:0.792
# Total time used: 195.5596306324005s, simulation ends at Mon Dec 19 03:49:59 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:50:01 2022
# PCS:0.797, PGS:0.797
# Total time used: 196.0006971359253s, simulation ends at Mon Dec 19 03:53:15 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:53:17 2022
# PCS:0.658, PGS:0.658
# Total time used: 196.43788623809814s, simulation ends at Mon Dec 19 03:56:31 2022
# The allocated ratio is 0.76
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:56:34 2022
# PCS:0.488, PGS:0.488
# Total time used: 169.58480501174927s, simulation ends at Mon Dec 19 03:59:22 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 03:59:24 2022
# PCS:0.816, PGS:0.816
# Total time used: 168.41161108016968s, simulation ends at Mon Dec 19 04:02:10 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:02:12 2022
# PCS:0.829, PGS:0.829
# Total time used: 167.87159705162048s, simulation ends at Mon Dec 19 04:04:58 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:05:00 2022
# PCS:0.629, PGS:0.629
# Total time used: 168.25483179092407s, simulation ends at Mon Dec 19 04:07:47 2022
# The allocated ratio is 0.79
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:07:49 2022
# PCS:0.465, PGS:0.465
# Total time used: 148.6699457168579s, simulation ends at Mon Dec 19 04:10:16 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:10:18 2022
# PCS:0.814, PGS:0.814
# Total time used: 146.76826095581055s, simulation ends at Mon Dec 19 04:12:43 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:12:45 2022
# PCS:0.82, PGS:0.82
# Total time used: 147.23961687088013s, simulation ends at Mon Dec 19 04:15:10 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:15:12 2022
# PCS:0.632, PGS:0.632
# Total time used: 147.83718633651733s, simulation ends at Mon Dec 19 04:17:38 2022
# The allocated ratio is 0.82
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:17:41 2022
# PCS:0.436, PGS:0.436
# Total time used: 128.33958983421326s, simulation ends at Mon Dec 19 04:19:47 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:19:49 2022
# PCS:0.82, PGS:0.82
# Total time used: 126.48866820335388s, simulation ends at Mon Dec 19 04:21:54 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:21:56 2022
# PCS:0.831, PGS:0.831
# Total time used: 126.96596908569336s, simulation ends at Mon Dec 19 04:24:01 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:24:03 2022
# PCS:0.649, PGS:0.649
# Total time used: 127.39347577095032s, simulation ends at Mon Dec 19 04:26:08 2022
# The allocated ratio is 0.85
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:26:11 2022
# PCS:0.408, PGS:0.408
# Total time used: 107.21875047683716s, simulation ends at Mon Dec 19 04:27:57 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:27:58 2022
# PCS:0.851, PGS:0.851
# Total time used: 107.81088066101074s, simulation ends at Mon Dec 19 04:29:44 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:29:46 2022
# PCS:0.833, PGS:0.833
# Total time used: 107.27143502235413s, simulation ends at Mon Dec 19 04:31:32 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:31:34 2022
# PCS:0.671, PGS:0.671
# Total time used: 108.14197707176208s, simulation ends at Mon Dec 19 04:33:20 2022
# The allocated ratio is 0.88
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:33:23 2022
# PCS:0.364, PGS:0.364
# Total time used: 87.56399440765381s, simulation ends at Mon Dec 19 04:34:49 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:34:51 2022
# PCS:0.832, PGS:0.832
# Total time used: 86.27274918556213s, simulation ends at Mon Dec 19 04:36:15 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:36:17 2022
# PCS:0.841, PGS:0.841
# Total time used: 86.37718844413757s, simulation ends at Mon Dec 19 04:37:41 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:37:43 2022
# PCS:0.672, PGS:0.672
# Total time used: 86.74367785453796s, simulation ends at Mon Dec 19 04:39:08 2022
# The allocated ratio is 0.9
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:39:11 2022
# PCS:0.334, PGS:0.334
# Total time used: 73.40906691551208s, simulation ends at Mon Dec 19 04:40:23 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:40:24 2022
# PCS:0.838, PGS:0.838
# Total time used: 72.77654004096985s, simulation ends at Mon Dec 19 04:41:35 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:41:37 2022
# PCS:0.837, PGS:0.837
# Total time used: 72.62965178489685s, simulation ends at Mon Dec 19 04:42:48 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:42:50 2022
# PCS:0.65, PGS:0.65
# Total time used: 72.98131775856018s, simulation ends at Mon Dec 19 04:44:01 2022
# The allocated ratio is 0.92
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:44:04 2022
# PCS:0.273, PGS:0.273
# Total time used: 60.69191908836365s, simulation ends at Mon Dec 19 04:45:03 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:45:05 2022
# PCS:0.837, PGS:0.837
# Total time used: 60.78121280670166s, simulation ends at Mon Dec 19 04:46:04 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:46:06 2022
# PCS:0.83, PGS:0.83
# Total time used: 60.12372064590454s, simulation ends at Mon Dec 19 04:47:04 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:47:06 2022
# PCS:0.651, PGS:0.651
# Total time used: 60.17872476577759s, simulation ends at Mon Dec 19 04:48:04 2022
# The allocated ratio is 0.94
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:48:07 2022
# PCS:0.188, PGS:0.188
# Total time used: 46.67182397842407s, simulation ends at Mon Dec 19 04:48:52 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:48:54 2022
# PCS:0.838, PGS:0.838
# Total time used: 46.02887797355652s, simulation ends at Mon Dec 19 04:49:38 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:49:40 2022
# PCS:0.831, PGS:0.831
# Total time used: 45.88936376571655s, simulation ends at Mon Dec 19 04:50:24 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:50:25 2022
# PCS:0.62, PGS:0.62
# Total time used: 46.232863903045654s, simulation ends at Mon Dec 19 04:51:10 2022
# The allocated ratio is 0.96
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:51:13 2022
# PCS:0.087, PGS:0.087
# Total time used: 32.68242049217224s, simulation ends at Mon Dec 19 04:51:44 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:51:46 2022
# PCS:0.785, PGS:0.785
# Total time used: 32.097020864486694s, simulation ends at Mon Dec 19 04:52:16 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:52:18 2022
# PCS:0.797, PGS:0.797
# Total time used: 32.01732563972473s, simulation ends at Mon Dec 19 04:52:48 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:52:50 2022
# PCS:0.621, PGS:0.621
# Total time used: 32.318942070007324s, simulation ends at Mon Dec 19 04:53:20 2022
# The allocated ratio is 0.98
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:53:23 2022
# PCS:0.021, PGS:0.021
# Total time used: 18.238831281661987s, simulation ends at Mon Dec 19 04:53:40 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:53:41 2022
# PCS:0.756, PGS:0.756
# Total time used: 18.17609453201294s, simulation ends at Mon Dec 19 04:53:58 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:00 2022
# PCS:0.752, PGS:0.752
# Total time used: 18.04269027709961s, simulation ends at Mon Dec 19 04:54:16 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:18 2022
# PCS:0.483, PGS:0.483
# Total time used: 18.254292249679565s, simulation ends at Mon Dec 19 04:54:34 2022
# The allocated ratio is 1.0
# ----------------------------------Generator Type 0--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:37 2022
# PCS:0.013, PGS:0.013
# Total time used: 4.1626670360565186s, simulation ends at Mon Dec 19 04:54:39 2022
# ----------------------------------Generator Type 1--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:41 2022
# PCS:0.131, PGS:0.131
# Total time used: 4.1243507862091064s, simulation ends at Mon Dec 19 04:54:43 2022
# ----------------------------------Generator Type 2--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:45 2022
# PCS:0.114, PGS:0.114
# Total time used: 4.160707473754883s, simulation ends at Mon Dec 19 04:54:48 2022
# ----------------------------------Generator Type 3--------------------------------
# EFG
# --------New experiments with  k=8192----------------------
# Start to simulate... at Mon Dec 19 04:54:50 2022
# PCS:0.045, PGS:0.045
# Total time used: 4.1347432136535645s, simulation ends at Mon Dec 19 04:54:52 2022
# [0.131, 0.158, 0.15, 0.101, 0.442, 0.498, 0.521, 0.394, 0.51, 0.632, 0.629, 0.466, 0.56, 0.685, 0.716, 0.567, 0.546, 0.744, 0.704, 0.571, 0.547, 0.756, 0.762, 0.59, 0.547, 0.762, 0.775, 0.611, 0.533, 0.77, 0.796, 0.638, 0.512, 0.783, 0.786, 0.614, 0.504, 0.792, 0.797, 0.658, 0.488, 0.816, 0.829, 0.629, 0.465, 0.814, 0.82, 0.632, 0.436, 0.82, 0.831, 0.649, 0.408, 0.851, 0.833, 0.671, 0.364, 0.832, 0.841, 0.672, 0.334, 0.838, 0.837, 0.65, 0.273, 0.837, 0.83, 0.651, 0.188, 0.838, 0.831, 0.62, 0.087, 0.785, 0.797, 0.621, 0.021, 0.756, 0.752, 0.483, 0.013, 0.131, 0.114, 0.045]

# %%
EFG_results
# Out:
# [0.1255,
#  0.15,
#  0.136,
#  0.1,
#  0.292,
#  0.4265,
#  0.4095,
#  0.3,
#  0.3415,
#  0.51,
#  0.49,
#  0.3715,
#  0.3395,
#  0.527,
#  0.5495,
#  0.4005,
#  0.341,
#  0.558,
#  0.583,
#  0.438,
#  0.3435,
#  0.6165,
#  0.5855,
#  0.4445,
#  0.3315,
#  0.5935,
#  0.6,
#  0.456,
#  0.308,
#  0.588,
#  0.616,
#  0.49,
#  0.3035,
#  0.6435,
#  0.6375,
#  0.4795,
#  0.2475,
#  0.6575,
#  0.6685,
#  0.4895,
#  0.2265,
#  0.669,
#  0.6525,
#  0.507,
#  0.214,
#  0.649,
#  0.6355,
#  0.4945,
#  0.1695,
#  0.651,
#  0.657,
#  0.5055,
#  0.0985,
#  0.662,
#  0.672,
#  0.524,
#  0.0615,
#  0.6665,
#  0.663,
#  0.4695,
#  0.029,
#  0.6605,
#  0.6545,
#  0.4835,
#  0.015,
#  0.6515,
#  0.648,
#  0.4575,
#  0.0115,
#  0.631,
#  0.6395,
#  0.416,
#  0.0025,
#  0.587,
#  0.585,
#  0.3385,
#  0.0015,
#  0.4675,
#  0.475,
#  0.1865,
#  0.006,
#  0.0375,
#  0.039,
#  0.0185]
